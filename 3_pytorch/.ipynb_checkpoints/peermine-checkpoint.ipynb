# %% [markdown]
# # Credits
# > This code is a slight modification to a translation (TensorFlow --> PyTorch) of a previous version of the [02456](http://kurser.dtu.dk/course/02456) course material.
# > [Original repo link (TensorFlow)](https://github.com/DeepLearningDTU/02456-deep-learning).
# > [Translated repo link (PyTorch)](https://github.com/munkai/pytorch-tutorial/tree/master/2_intermediate).

# %%
import torch
from torch.autograd import Variable
from torch.nn.parameter import Parameter
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torch.nn.init as init

# %matplotlib inline
import matplotlib
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # MNIST dataset
# MNIST is a dataset that is often used for benchmarking. The MNIST dataset consists of 70,000 images of handwritten digits from 0-9. The dataset is split into a 50,000 images training set, 10,000 images validation set and 10,000 images test set. The images are 28x28 pixels, where each pixel represents a normalised value between 0-255 (0=black and 255=white).
#
# ![MNIST.Exampel](../static_files/mnist.png)
#
#
# ## Primer
# We use a feedforward neural network to classify the 28x28 mnist images. `num_features` is therefore $28 * 28=784$, i.e. we represent each image as a vector. The ordering of the pixels in the vector does not matter, so we could permutate all images using the same permutation and still get the same performance. (You are of course encouraged to try this using ``numpy.random.permutation`` to get a random permutation. This task is therefore called the _permutation invariant_ MNIST. Obviously this throws away a lot of structure in the data. In the next module we'll fix this with the convolutional neural network wich encodes prior knowledgde about data that has either spatial or temporal structure.

# %% [markdown]
# ## MNIST
# First let's load the MNIST dataset and plot a few examples:

# %% [raw]
# !if [ ! -f mnist.npz ]; then wget -N https://github.com/maximai/placeholder_repo/raw/master/mnist.npz; else echo "mnist.npz already downloaded"; fi

# %%
#To speed up training we'll only work on a subset of the data
filename = '../input/mnist.npz'
data = np.load(filename)
num_classes = 10
x_train = data['X_train'][:1000].astype('float32')
targets_train = data['y_train'][:1000].astype('int32')

x_valid = data['X_valid'][:500].astype('float32')
targets_valid = data['y_valid'][:500].astype('int32')

x_test = data['X_test'][:500].astype('float32')
targets_test = data['y_test'][:500].astype('int32')

print("Information on dataset")
print("x_train", x_train.shape)
print("targets_train", targets_train.shape)
print("x_valid", x_valid.shape)
print("targets_valid", targets_valid.shape)
print("x_test", x_test.shape)
print("targets_test", targets_test.shape)
# Out:
# Information on dataset
# x_train (1000, 784)
# targets_train (1000,)
# x_valid (500, 784)
# targets_valid (500,)
# x_test (500, 784)
# targets_test (500,)

# %%
#plot a few MNIST examples
idx, dim, classes = 0, 28, 10
# create empty canvas
canvas = np.zeros((dim*classes, classes*dim))

# fill with tensors
for i in range(classes):
    for j in range(classes):
        canvas[i*dim:(i+1)*dim, j*dim:(j+1)*dim] = x_train[idx].reshape((dim, dim))
        idx += 1

# visualize matrix of tensors as gray scale image
plt.figure(figsize=(4, 4))
plt.axis('off')
plt.imshow(canvas, cmap='gray')
plt.title('MNIST handwritten digits')
plt.show()

# %% [markdown]
# ## Model
#
# One of the large challenges in deep learning is the amount of hyperparameters that needs to be selected, and the lack of a good principled way of selecting them.
# Hyperparameters can be found by experience (guessing) or some search procedure (often quite slow).
# Random search is easy to implement and performs decent: http://www.jmlr.org/papers/volume13/bergstra12a/bergstra12a.pdf .
# More advanced search procedures include [Spearmint](https://github.com/JasperSnoek/spearmint) and many others.
#
# **In practice a lot of trial and error is almost always involved.** This can be frustrating and time consuming, but the best thing to do is to think as a scientist, and go about it in a ordered manner --> monitor as much as you can, take notes, and be deliberate!
#
# Below are some guidelines that you can use as a starting point to some of the most important hyperparameters.
# (*regularization* is also very important, but will be covered later.)
#
#
# ### Ballpark estimates of hyperparameters
# __Number of hidden units and network structure:__
# You'll have to experiment. One rarely goes below 512 units for feedforward networks (unless your are training on CPU...).
# There's some research into stochastic depth networks: https://arxiv.org/pdf/1603.09382v2.pdf, but in general this is trial and error.
#
# __Parameter initialization:__
# Parameter initialization is extremely important.
# PyTorch has a lot of different initializers, check the [PyTorch API](http://pytorch.org/docs/master/nn.html#torch-nn-init). Often used initializer are
# 1. Kaming He
# 2. Xavier Glorot
# 3. Uniform or Normal with small scale (0.1 - 0.01)
# 4. Orthogonal (this usually works very well for RNNs)
#
# Bias is nearly always initialized to zero using the [torch.nn.init.constant(tensor, val)](http://pytorch.org/docs/master/nn.html#torch.nn.init.constant)
#
# __Mini-batch size:__
# Usually people use 16-256. Bigger is not allways better. With smaller mini-batch size you get more updates and your model might converge faster. Also small batch sizes use less memory, which means you can train a model with more parameters.
#
# __Nonlinearity:__ [The most commonly used nonliearities are](http://pytorch.org/docs/master/nn.html#non-linear-activations)
# 1. ReLU
# 2. Leaky ReLU
# 3. Elu
# 3. Sigmoid squash the output [0, 1], and are used if your output is binary (not used in the hidden layers)
# 4. Tanh is similar to sigmoid, but squashes in [-1, 1]. It is rarely used any more.
# 4. Softmax normalizes the the output to 1, and is used as output if you have a classification problem
#
# See the plot below.
#
# __Optimizer and learning rate:__
# 1. SGD + Momentum: learning rate 1.0 - 0.1
# 2. ADAM: learning rate 3*1e-4 - 1e-5
# 3. RMSPROP: somewhere between SGD and ADAM

# %%
# Illustrate different output units
x = np.linspace(-6, 6, 100)
units = {
    "ReLU": lambda x: np.maximum(0, x),
    "Leaky ReLU": lambda x: np.maximum(0, x) + 0.1 * np.minimum(0, x),
    "Elu": lambda x: (x > 0) * x + (1 - (x > 0)) * (np.exp(x) - 1),
    "Sigmoid": lambda x: (1 + np.exp(-x))**(-1),
    "tanh": lambda x: (np.exp(x) - np.exp(-x)) / (np.exp(x) + np.exp(-x))
}

plt.figure(figsize=(5, 5))
[plt.plot(x, unit(x), label=unit_name, lw=2) for unit_name, unit in units.items()]
plt.legend(loc=2, fontsize=16)
plt.title('Non-linearities', fontsize=20)
plt.ylim([-2, 5])
plt.xlim([-6, 6])

# assert that all class probablities sum to one
softmax = lambda x: np.exp(x) / np.sum(np.exp(x))
print("softmax should sum to one (approxiamtely):", np.sum(softmax(x)))
# Out:
# softmax should sum to one (approxiamtely): 1.0

# %%
# define network
class Net(nn.Module):

    def __init__(self, 
                 num_features, 
                 num_hidden, 
                 num_output, 
                 middle_layer=False, 
                 activation=torch.nn.ELU(), 
                 initializer=init.xavier_normal_,
                 dropout=False,
                 batchnorm=False):
        
        super(Net, self).__init__()  
        # input layer
        self.W_1 = Parameter(initializer(torch.Tensor(num_hidden, num_features)))
        self.b_1 = Parameter(init.constant_(torch.Tensor(num_hidden), 0))
        
        # hidden layer
        self.W_middle = Parameter(initializer(torch.Tensor(num_hidden, num_hidden)))
        self.b_middle = Parameter(init.constant_(torch.Tensor(num_hidden), 0))
        
        # hidden layer
        self.W_2 = Parameter(initializer(torch.Tensor(num_output, num_hidden)))
        self.b_2 = Parameter(init.constant_(torch.Tensor(num_output), 0))
        
        # define activation function in constructor
        self.activation = activation
        self.middle_layer = middle_layer
        
        # Define dropout function
        self.dropout = dropout
        self.dropout_func = nn.Dropout(p=0.5)
        
        # Define batch normalization function
        self.batchnorm = batchnorm
        

    def forward(self, x):
        # First layer
        x = F.linear(x, self.W_1, self.b_1)
        x = nn.BatchNorm1d(x.shape[1])(x) if self.batchnorm else x
        x = self.activation(x)
        x = self.dropout_func(x) if self.dropout else x
        
        # Run through a middle layer if applicable
        if self.middle_layer:
            x = F.linear(x, self.W_middle, self.b_middle)
            x = nn.BatchNorm1d(x.shape[1])(x) if self.batchnorm else x
            x = self.activation(x)
            x = self.dropout_func(x) if self.dropout else x
            
        # Final layer
        x = F.linear(x, self.W_2, self.b_2)
        x = nn.BatchNorm1d(x.shape[1])(x) if self.batchnorm else x
        x = F.softmax(x, dim=1)
        
        return x

# %%
#Hyperparameters
num_classes = 10
num_l1 = 512
num_features = x_train.shape[1]

# %%
#Test the forward pass with dummy data
x = np.random.normal(0, 1, (45, dim*dim)).astype('float32')

net_relu = Net(num_features, 
               num_l1, 
               num_classes, 
               initializer=init.xavier_normal_, 
               middle_layer=True, 
               activation=torch.nn.ReLU(),
               dropout=False,
               batchnorm=True)

print(net_relu(Variable(torch.from_numpy(x))).size())
# Out:
# torch.Size([45, 10])

# %% [markdown]
# # Build the training loop
#
# We train the network by calculating the gradient w.r.t the cost function and update the parameters in direction of the negative gradient.
#
#
# When training neural network you always use mini batches. Instead of calculating the average gradient using the entire dataset you approximate the gradient using a mini-batch of typically 16 to 256 samples. The paramters are updated after each mini batch. Networks converge much faster using mini batches because the parameters are updated more often.
#
# We build a loop that iterates over the training data. Remember that the parameters are updated each time ``optimizer.step()`` is called.

# %%
# we could have done this ourselves,
# but we should be aware of sklearn and it's tools
from sklearn.metrics import accuracy_score

def train_loop(net, 
               dataset, 
               algorithm=optim.SGD, 
               momentum=0, 
               learning_rate=0.1, 
               batch_size=100, 
               num_epochs=100,
               dropout=False,
               weight_decay=0):
    
    # Set optimizer algorithm and loss
    loss_function = nn.CrossEntropyLoss()
    
    if algorithm == optim.SGD:
        optimizer = algorithm(net.parameters(), 
                              lr=learning_rate, 
                              momentum=momentum,
                              weight_decay=weight_decay)
    else:
        optimizer = algorithm(net.parameters(), 
                              lr=learning_rate,
                              weight_decay=weight_decay)
    
    # Split dataset tuple
    x_train, x_valid, x_test, targets_train, targets_valid, targets_test = dataset

    # Set batch lists
    num_samples_train = x_train.shape[0]
    num_batches_train = num_samples_train // batch_size
    num_samples_valid = x_valid.shape[0]
    num_batches_valid = num_samples_valid // batch_size

    # Set loss/accuracy lists
    train_acc, train_loss = [], []
    valid_acc, valid_loss = [], []
    test_acc, test_loss = [], []
    cur_loss = 0
    losses = []
    
    get_slice = lambda i, size: range(i * size, (i + 1) * size)

    for epoch in range(num_epochs):
        # Forward -> Backprob -> Update params
        ## Train
        cur_loss = 0
        net.train()
        for i in range(num_batches_train):
            slce = get_slice(i, batch_size)
            x_batch = Variable(torch.from_numpy(x_train[slce]))
            output = net(x_batch)

            # compute gradients given loss
            target_batch = Variable(torch.from_numpy(targets_train[slce]).long())
            batch_loss = loss_function(output, target_batch)
            optimizer.zero_grad()
            batch_loss.backward()
            optimizer.step()
            cur_loss += batch_loss
        
        # Save loss
        losses.append(cur_loss / batch_size)

        net.eval()
        ### Evaluate training
        train_preds, train_targs = [], []
        for i in range(num_batches_train):
            slce = get_slice(i, batch_size)
            x_batch = Variable(torch.from_numpy(x_train[slce]))

            output = net(x_batch)
            preds = torch.max(output, 1)[1]

            train_targs += list(targets_train[slce])
            train_preds += list(preds.data.numpy())

        ### Evaluate validation
        val_preds, val_targs = [], []
        for i in range(num_batches_valid):
            slce = get_slice(i, batch_size)
            x_batch = Variable(torch.from_numpy(x_valid[slce]))

            output = net(x_batch)
            preds = torch.max(output, 1)[1]
            val_preds += list(preds.data.numpy())
            val_targs += list(targets_valid[slce])

        train_acc_cur = accuracy_score(train_targs, train_preds)
        valid_acc_cur = accuracy_score(val_targs, val_preds)

        train_acc.append(train_acc_cur)
        valid_acc.append(valid_acc_cur)

        if epoch % 10 == 0:
            print("Epoch %2i : Train Loss %f , Train acc %f, Valid acc %f" % (
                    epoch+1, losses[-1], train_acc_cur, valid_acc_cur))

    epoch = np.arange(len(train_acc))
    plt.figure()
    plt.plot(epoch, train_acc, 'r', epoch, valid_acc, 'b')
    plt.legend(['Train Accucary','Validation Accuracy'])
    plt.xlabel('Updates'), plt.ylabel('Acc')

# %% [markdown]
# # Assignments
#
# Try and add these modifications (might require some Googleing -- an important skill in deep learning):
# - Kaiming He initialization instead of Xavier Glorot
# - add an extra layer
# - use the relu activation function
# - add momentum to the optimizer
# - use the ADAM optimizer instead of stochastic gradient descent
#
# ### Advanced - Regularization
#
# Regularization is VERY important in practice and is used practically every time.
# Many important results are completely dependent on cleaver use of regularization, and it is something you need to become familiar with if you want to work with deep learning.
#
# - add L1 or L2 weight regularization (aka. weight decay)
# - add dropout to the network (**note** the `net.train()` and `net.eval()` are already in the code)
# - add batchnorm
#
# __Pointers on regularization hyperparameter:__
# 1. L2 and [L1 regularization](http://pytorch.org/docs/master/nn.html#torch.nn.L1Loss) (weight decay of optimization functions)
#   - Normal ranges: 1e-4  -  1e-8
# 1. [Dropout](http://pytorch.org/docs/master/nn.html?highlight=dropout#torch.nn.Dropout). Dropout rate 0.1-0.5
#   - Remember to pick the correct version according to the input dimensionality
#   - **NOTE** call `net.train()` before training to activate random dropout, and call `net.eval()` to deactivate dropout while validating or running inference with model.
# 1. [Batchnorm](http://pytorch.org/docs/master/nn.html#torch.nn.BatchNorm1d): Batchnorm also acts as a regularizer - Often very useful (faster and better convergence)
#   - Remember to pick the correct version according to the input dimensionality
#   - **NOTE** call `net.train()` before training to activate, and call `net.eval()` to have a non-stochastic variant while validating or running inference with model.

# %%
X = (x_train, x_valid, x_test, targets_train, targets_valid, targets_test)

# %% [markdown]
# ### Kaiming He Initialization (normal distributed)

# %%
net_kaiming = Net(num_features, num_l1, num_classes, initializer=init.kaiming_normal_)
train_loop(net_kaiming, X)
# Out:
# Epoch  1 : Train Loss 0.228123 , Train acc 0.295000, Valid acc 0.288000
# Epoch 11 : Train Loss 0.180464 , Train acc 0.796000, Valid acc 0.706000
# Epoch 21 : Train Loss 0.168150 , Train acc 0.856000, Valid acc 0.764000
# Epoch 31 : Train Loss 0.163830 , Train acc 0.879000, Valid acc 0.778000
# Epoch 41 : Train Loss 0.160777 , Train acc 0.905000, Valid acc 0.806000
# Epoch 51 : Train Loss 0.158267 , Train acc 0.920000, Valid acc 0.820000
# Epoch 61 : Train Loss 0.156680 , Train acc 0.934000, Valid acc 0.814000
# Epoch 71 : Train Loss 0.155562 , Train acc 0.940000, Valid acc 0.828000
# Epoch 81 : Train Loss 0.154688 , Train acc 0.942000, Valid acc 0.830000
# Epoch 91 : Train Loss 0.153973 , Train acc 0.950000, Valid acc 0.832000

# %% [markdown]
# ### Extra layer

# %%
net_3_layers = Net(num_features, 
                   num_l1, 
                   num_classes, 
                   initializer=init.xavier_normal_, 
                   middle_layer=True)

train_loop(net_3_layers, X)
# Out:
# Epoch  1 : Train Loss 0.228406 , Train acc 0.312000, Valid acc 0.300000
# Epoch 11 : Train Loss 0.176111 , Train acc 0.791000, Valid acc 0.716000
# Epoch 21 : Train Loss 0.166886 , Train acc 0.837000, Valid acc 0.756000
# Epoch 31 : Train Loss 0.163576 , Train acc 0.859000, Valid acc 0.752000
# Epoch 41 : Train Loss 0.161719 , Train acc 0.870000, Valid acc 0.756000
# Epoch 51 : Train Loss 0.160497 , Train acc 0.875000, Valid acc 0.758000
# Epoch 61 : Train Loss 0.154927 , Train acc 0.949000, Valid acc 0.820000
# Epoch 71 : Train Loss 0.153019 , Train acc 0.957000, Valid acc 0.832000
# Epoch 81 : Train Loss 0.151945 , Train acc 0.961000, Valid acc 0.834000
# Epoch 91 : Train Loss 0.151111 , Train acc 0.969000, Valid acc 0.840000

# %% [markdown]
# ### Use the relu activation function

# %%
net_relu = Net(num_features, 
               num_l1, 
               num_classes, 
               initializer=init.xavier_normal_, 
               middle_layer=True, 
               activation=torch.nn.ReLU())

train_loop(net_relu, X, learning_rate=0.1)
# Out:
# Epoch  1 : Train Loss 0.230237 , Train acc 0.125000, Valid acc 0.114000
# Epoch 11 : Train Loss 0.196577 , Train acc 0.576000, Valid acc 0.548000
# Epoch 21 : Train Loss 0.174790 , Train acc 0.807000, Valid acc 0.722000
# Epoch 31 : Train Loss 0.162034 , Train acc 0.913000, Valid acc 0.814000
# Epoch 41 : Train Loss 0.157419 , Train acc 0.932000, Valid acc 0.830000
# Epoch 51 : Train Loss 0.154964 , Train acc 0.946000, Valid acc 0.848000
# Epoch 61 : Train Loss 0.153360 , Train acc 0.954000, Valid acc 0.850000
# Epoch 71 : Train Loss 0.152334 , Train acc 0.957000, Valid acc 0.854000
# Epoch 81 : Train Loss 0.151582 , Train acc 0.960000, Valid acc 0.854000
# Epoch 91 : Train Loss 0.150983 , Train acc 0.965000, Valid acc 0.856000

# %% [markdown]
# ### Add momentum to the optimizer

# %%
net_relu = Net(num_features, 
               num_l1, 
               num_classes, 
               initializer=init.xavier_normal_, 
               middle_layer=True, 
               activation=torch.nn.ReLU())

train_loop(net_relu, X, momentum=0.9, learning_rate=0.1)
# Out:
# Epoch  1 : Train Loss 0.228706 , Train acc 0.450000, Valid acc 0.416000
# Epoch 11 : Train Loss 0.154257 , Train acc 0.944000, Valid acc 0.818000
# Epoch 21 : Train Loss 0.149684 , Train acc 0.970000, Valid acc 0.850000
# Epoch 31 : Train Loss 0.148904 , Train acc 0.974000, Valid acc 0.848000
# Epoch 41 : Train Loss 0.148774 , Train acc 0.974000, Valid acc 0.848000
# Epoch 51 : Train Loss 0.148647 , Train acc 0.975000, Valid acc 0.850000
# Epoch 61 : Train Loss 0.148625 , Train acc 0.975000, Valid acc 0.852000
# Epoch 71 : Train Loss 0.148613 , Train acc 0.975000, Valid acc 0.854000
# Epoch 81 : Train Loss 0.148605 , Train acc 0.975000, Valid acc 0.854000
# Epoch 91 : Train Loss 0.148597 , Train acc 0.975000, Valid acc 0.852000

# %% [markdown]
# ### Use the ADAM optimizer instead of stochastic gradient descent

# %%
net_relu = Net(num_features, 
               num_l1, 
               num_classes, 
               initializer=init.xavier_normal_, 
               middle_layer=True, 
               activation=torch.nn.ReLU())

train_loop(net_relu, X, algorithm=optim.Adam, learning_rate=0.001)
# Out:
# Epoch  1 : Train Loss 0.209572 , Train acc 0.735000, Valid acc 0.680000
# Epoch 11 : Train Loss 0.148951 , Train acc 0.978000, Valid acc 0.856000
# Epoch 21 : Train Loss 0.147933 , Train acc 0.982000, Valid acc 0.862000
# Epoch 31 : Train Loss 0.147801 , Train acc 0.983000, Valid acc 0.860000
# Epoch 41 : Train Loss 0.147789 , Train acc 0.983000, Valid acc 0.860000
# Epoch 51 : Train Loss 0.147691 , Train acc 0.984000, Valid acc 0.862000
# Epoch 61 : Train Loss 0.147691 , Train acc 0.984000, Valid acc 0.860000
# Epoch 71 : Train Loss 0.147597 , Train acc 0.985000, Valid acc 0.850000
# Epoch 81 : Train Loss 0.148986 , Train acc 0.980000, Valid acc 0.834000
# Epoch 91 : Train Loss 0.147472 , Train acc 0.988000, Valid acc 0.870000

# %% [markdown]
# ### Add L1/L2 regularization

# %%
net_relu = Net(num_features, 
               num_l1, 
               num_classes, 
               initializer=init.xavier_normal_, 
               middle_layer=True, 
               activation=torch.nn.ReLU())

train_loop(net_relu, 
           X, 
           algorithm=optim.Adam, 
           learning_rate=0.001, 
           weight_decay=1e-4)
# Out:
# Epoch  1 : Train Loss 0.210052 , Train acc 0.722000, Valid acc 0.660000
# Epoch 11 : Train Loss 0.149325 , Train acc 0.973000, Valid acc 0.852000
# Epoch 21 : Train Loss 0.148104 , Train acc 0.982000, Valid acc 0.850000
# Epoch 31 : Train Loss 0.147766 , Train acc 0.985000, Valid acc 0.860000
# Epoch 41 : Train Loss 0.147650 , Train acc 0.985000, Valid acc 0.864000
# Epoch 51 : Train Loss 0.147653 , Train acc 0.985000, Valid acc 0.864000
# Epoch 61 : Train Loss 0.147653 , Train acc 0.985000, Valid acc 0.864000
# Epoch 71 : Train Loss 0.147648 , Train acc 0.985000, Valid acc 0.862000
# Epoch 81 : Train Loss 0.147500 , Train acc 0.988000, Valid acc 0.864000
# Epoch 91 : Train Loss 0.148596 , Train acc 0.986000, Valid acc 0.856000

# %% [markdown]
# ### Add dropout

# %%
net_relu = Net(num_features, 
               num_l1, 
               num_classes, 
               initializer=init.xavier_normal_, 
               middle_layer=True, 
               activation=torch.nn.ReLU(),
               dropout=True)

train_loop(net_relu, 
           X, 
           algorithm=optim.Adam, 
           learning_rate=0.001)
# Out:
# Epoch  1 : Train Loss 0.220625 , Train acc 0.500000, Valid acc 0.462000
# Epoch 11 : Train Loss 0.154798 , Train acc 0.960000, Valid acc 0.846000
# Epoch 21 : Train Loss 0.150124 , Train acc 0.980000, Valid acc 0.864000
# Epoch 31 : Train Loss 0.148600 , Train acc 0.984000, Valid acc 0.870000
# Epoch 41 : Train Loss 0.147863 , Train acc 0.986000, Valid acc 0.880000
# Epoch 51 : Train Loss 0.147661 , Train acc 0.986000, Valid acc 0.874000
# Epoch 61 : Train Loss 0.147508 , Train acc 0.987000, Valid acc 0.876000
# Epoch 71 : Train Loss 0.147508 , Train acc 0.987000, Valid acc 0.880000
# Epoch 81 : Train Loss 0.147729 , Train acc 0.987000, Valid acc 0.862000
# Epoch 91 : Train Loss 0.147479 , Train acc 0.988000, Valid acc 0.874000

# %% [markdown]
# ### Add batchnorm

# %%
net_relu = Net(num_features, 
               num_l1, 
               num_classes, 
               initializer=init.xavier_normal_, 
               middle_layer=True, 
               activation=torch.nn.ReLU(),
               dropout=False,
               batchnorm=True)

train_loop(net_relu, 
           X, 
           algorithm=optim.Adam, 
           learning_rate=0.001)
# Out:
# Epoch  1 : Train Loss 0.221205 , Train acc 0.682000, Valid acc 0.590000
# Epoch 11 : Train Loss 0.207354 , Train acc 0.924000, Valid acc 0.808000
# Epoch 21 : Train Loss 0.203506 , Train acc 0.972000, Valid acc 0.782000
# Epoch 31 : Train Loss 0.206682 , Train acc 0.985000, Valid acc 0.808000
# Epoch 41 : Train Loss 0.202851 , Train acc 0.987000, Valid acc 0.792000
# Epoch 51 : Train Loss 0.206736 , Train acc 0.996000, Valid acc 0.804000
# Epoch 61 : Train Loss 0.205331 , Train acc 0.992000, Valid acc 0.836000
# Epoch 71 : Train Loss 0.206312 , Train acc 0.994000, Valid acc 0.822000
# Epoch 81 : Train Loss 0.201349 , Train acc 0.993000, Valid acc 0.822000
# Epoch 91 : Train Loss 0.203217 , Train acc 0.998000, Valid acc 0.774000

# %% [markdown]
# You are done for now. [Good job.](https://media1.tenor.com/images/0fd559b07f2174f9b8b7dbde7c5a67ca/tenor.gif)

# %% [markdown]
# ## Michael Nielsen Exericse
# * Exercise #1 from http://neuralnetworksanddeeplearning.com/chap3.html#overfitting_and_regularization
#
# ### Question
# _One gotcha with the cross-entropy is that it can be difficult at first to remember the respective roles of the ys and the as. It's easy to get confused about whether the right form is:_
# $$y \cdot ln(a) + (1−y) \cdot ln(1−a)$$
# $$\text{or}$$
# $$−a \cdot ln(y) + (1−a) \cdot ln(1−y)$$
#
# _What happens to the second of these expressions when y=0 or 1? Does this problem afflict the first expression? Why or why not?_
#
# ### Answer
# With $a = \sigma (z)$, the second expression encounters a problem when $y=0$, since $ln(0)$ is undefined.
#
# The first expression does not suffer from this since $0 < a < 1$, meaning $ln(a)$ is well-defined for all values of $a$. This follows from the definition of the sigmoid function $$a = \sigma (z) = \frac{1}{1 + exp(-z)}$$
